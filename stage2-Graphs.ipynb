# %% [markdown]
# # Graphs of univariate distribution of all non funding variables

# %%
import pandas as pd
data=pd.read_excel('G:/redcarpet/datamodified.xls') 

data["Agency"].value_counts().plot(kind = "barh")

#data["Subagency"].value_counts().plot(kind = "bar") - very complex

# %%
z=[0,0,1,2,3,2,1,0]
#finding dictionary of labels and frequency 
import collections
g = collections.Counter(z)
print(g)
print(len(g))

#finding labels and frequency

a = {'col1': z}
new_df = pd.DataFrame(data=a)
t_u = new_df['col1'].unique()
l = len(t_u)
freq =[]
labels = []
for i in range(0,l):
        x=new_df.loc[new_df['col1'] == t_u[i]]
        freq.append(len(x))
        labels.append(t_u[i])
    
print(labels)
print("hi")
print(freq)
#print(len(labels))

# %%
import pandas as pd
df=pd.read_excel('G:/redcarpet/datamodified.xls') 
t_u = df["B) Year Established"].unique()
l = len(t_u)
freq =[]
labels = []
for i in range(0,l):
        x=df.loc[df["B) Year Established"]== t_u[i]]
        freq.append(len(x))
        labels.append(t_u[i])

# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(labels,freq,s =100)
plt.xlabel("Year_established")
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # PieCharts

# %%
#data['D) Mission-specific or General STEM?'].value_counts()
data['D) Mission-specific or General STEM?'].value_counts().plot(kind = "pie",figsize=[10, 10],autopct='%1.1f%%')

# %%
labels =["Mission-related","Agency workforce"]
          
sizes =[104,6]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
plt.pie(sizes,labels=labels,colors=colors
       ,autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Agency or Mission-Related Workforce Needs?",color="blue")

#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()

# %%
data['F1) Primary Investment Objective'].value_counts().plot(kind = "barh")

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


import pandas as pd
df=pd.read_excel('G:/redcarpet/datamodified.xls')         
objects = ("objective-1","objective-2","objective-3","objective-4","objective-5","objective-6","objective-7","objective-8","objective-9","objective-10")
y_pos = np.arange(len(objects))
performance = [137,123,81,87,101,88,26,40,54,4]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Frequency')
plt.title('Secondary Objectives')
pl.xticks(rotation = 90) 
plt.show()
#Learning:Develop STEM skills, practices, or knowledge of students or the public    137 -obj 1
    
#Engagement: Increase learners’ engagement, interest in STEM and their perception of its value to their lives, or their ability 
# or participate in STEM    123- obj2  
    
#Pre and In Service Educator/Education Leader Performance: Train or retain STEM educators (K-12 pre-service or in-service, 
#post-secondary, and informal) and education leaders to improve the content knowledge and pedagogical 
#skills of STEM educators    81-obj 3

#Post-Secondary STEM Degrees: Increase the number of students who enroll in STEM majors, complete STEM credentials or degree programs, or are
#  prepared to enter STEM careers or advanced education    87 -obj 4


#STEM Careers: Prepare people to enter STEM workforce with training or certification (where STEM discipline specific knowledge and skill are the
# primary focus of the education investment; STEM educator training and development investments should select the Pre and In Service Educator/Education
# Leader Performance objective listed above)    101  -obj 5  
    
#Institutional Capacity: Support advancement and development of STEM personnel, programs, and infrastructure in educational institutions 
#such as universities, informal education institutions, state education agencies, and local education agencies    88    -obj 6

#STEM System Reform: Improve STEM education through a focus on education system reform    26 -obj 7   
    
#Education Research and Development: Develop evidence-based STEM education models and practices    40-obj 8
    
#Other    54 -obj 9

#Coordinate and support a community of practice of STEM E/PO professionals at \nNASA Centers, research and STEM education organizations and institutions; 
#help \nto enhance communications, collaborations, and partnerships. 4-obj 10

# %%
#print(df.columns.values)
#print(df['G1) Primary Research Approaches'].value_counts())
#print("\n")
#print(df['Unnamed: 23'].value_counts())
#print("\n")
#print(df['Unnamed: 24'].value_counts())
#print("\n")
#print(df['Unnamed: 25'].value_counts())
#print("\n")
#print(df['Unnamed: 26'].value_counts())








labels =["PRA1","PRA2","PRA3","PRA4","PRA5"]
          
sizes =[14,18,48,43,48]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral',"pink"]
plt.pie(sizes,labels=labels,colors=colors
       ,autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Primary Research Approaches",color="blue")

#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()



#Basic/Foundational Education Research: Research on STEM learning, teaching, or education practices/materials/technology,14 -Ap1
    

#Disciplinary Education Research and Development: Research and development interwoven to improve STEM learning and teaching,
#within a single STEM discipline or across specific disciplines (e.g. learning trajectories research),18 -Ap2   


#Small-Scale Implementation: STEM education projects, techniques, models, resources, and/or technologies used with a 
#relatively small group of learners or educators in one or several (<10) classrooms, museums, schools, etc,48 -Ap3

#Building Capacity of People or Organizations: Development of human and institutional capacity to develop, test, adapt 
#and implement effective STEM education work,43 -Ap4


#Large Scale Deployment: STEM education projects, techniques, models, resources, and/or technologies implemented at 
#the state, regional, or national scale ,48-Ap5

# %%
#print(df.columns.values)
#print(df['G2) Secondary Research Approaches'].value_counts())
#print("\n")
#print(df['Unnamed: 28'].value_counts())
#print("\n")
#print(df['Unnamed: 29'].value_counts())
#print("\n")
#print(df['Unnamed: 30'].value_counts())
#print("\n")
#print(df['Unnamed: 31'].value_counts())


objects = ("SRA1","SRA2","SRA3","SRA4","SRA5")
y_pos = np.arange(len(objects))
performance = [23,38,45,44,33]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral',"pink"]
plt.bar(y_pos, performance, align='center', alpha=0.5,color=colors)
plt.xticks(y_pos, objects)
plt.ylabel('Frequency')
plt.title('Secondary Research Approaches')
 
plt.show()



#Basic/Foundational Education Research: Research on STEM learning, teaching, or education practices/materials/technology    23
#Name: G2) Secondary Research Approaches, dtype: int64 -Ap-1
        
#Disciplinary Education Research and Development: Research and development interwoven to improve STEM learning and 
#teaching, within a single STEM discipline or across specific disciplines (e.g. learning trajectories research)-Ap-2    38  

#Small-Scale Implementation: STEM education projects, techniques, models, resources, and/or technologies used
#with a relatively small group of learners or educators in one or several (<10) classrooms, museums, schools, etc-Ap-3    45


#Building Capacity of People or Organizations: Development of human and institutional capacity to develop,  44
#test, adapt and implement effective STEM education work-Ap-4    

#Large Scale Deployment: STEM education projects, techniques, models, resources, and/or  33 
#technologies implemented at the state, regional, or national scale -Ap-5

# %%
#print(df.columns.values)

labels =["sp-1","sp-2","sp-3","sp-4","sp-5","sp-6","sp-7","sp-8","sp-9","sp-10","sp-11","sp-12","sp-13","sp-14","sp-15","sp-16","sp-17","sp-18","sp-19","sp-20","sp-21","sp-22"]
          
sizes =[113,139,112,96,102,33,30,180,92,124,173,2,48,45,4,36,2,40,1,46,2,73]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']





y_pos = np.arange(len(labels))
plt.bar(y_pos, sizes, align='center', alpha=0.5,color = colors)
plt.xticks(y_pos, labels,rotation=90)
plt.ylabel('Frequency')
plt.title('Educational Services or Products Produced')
 
plt.show()



#Direct classroom instruction to students    113,sp-1
#Instructional material development    139,sp-2
#Online education resource sites (e.g., online digital libraries)    112,sp-3
#Fellowship or scholarships (for educators or students)    96,sp-4
#Internship (short-term STEM employment)    102,sp-5
#Recognition awards    33,sp-6
#Competition         30,sp-7
#Engagement in authentic STEM experience (including research)    180,sp-8
#Learning program (i.e., after-school, weekend, or summer program)         92,sp-9
#Tutoring, mentoring, or other learner support    124,sp-10
#Training or professional development    173,sp-11
#Loan forgiveness    2,sp-12
#Education research to improve STEM teaching and learning    48,sp-13
#Implementation of assessment    45,sp-14
#Assessment implementation        4,sp-15
#Development of assessment    36,sp-16
#Assessment development        2,sp-17
#Infrastructure support   40 ,sp-18                                                                                                                                               40
#Institutional support for infrastructure (to strengthen STEM education capabilities though expansion of facilities, 
#classrooms, technology, and other physical infrastructure)  1,sp-19
#Administrative support                         46,sp-20
#Institutional support for leadership, management, and administrative activities     2,sp-21
#Other  73,sp-22

# %%
#print(df.columns.values)

#print(df['I1) STEM Learners Targeted? Specify.'].value_counts())
#print("\n")
#print(df['Unnamed: 57'].value_counts())
#print("\n")
#print(df['Unnamed: 58'].value_counts())
#print("\n")
#print(df['Unnamed: 59'].value_counts())
#print("\n")
#print(df['Unnamed: 60'].value_counts())
#print("\n")
#print(df['Unnamed: 61'].value_counts())
#print("\n")
#print(df['Unnamed: 62'].value_counts())
#print("\n")
#print(df['Unnamed: 63'].value_counts())



objects = ("LT-1","LT-2","LT-3","LT-4","LT-5","LT-6","LT-7","LT-8","LT-9","LT-10","LT-11","LT-12","LT-13")
y_pos = np.arange(len(objects))
performance = [105,104,14,63,73,7,77,11,80,51,74,30,94]
 
plt.bar(y_pos, performance, align='center', alpha=0.5,color ="green")
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Frequency')
plt.title('STEM Learners Targeted')
 
plt.show()

#Pre-K-20 learners            105   -LT-1
#Grades 6-20 aged learners    104 -LT-2
#Pre-K    14   -LT-3
#Elementary school (K-5) aged learners    63   -LT-4
#Middle school (6-8) aged learners    73   -LT-5
#Middle (6-8)                          7   -LT-6
#High school (9-12) aged learners    77   -LT-7
#High school (9-12)                  11   -LT-8
#Undergraduate (13-16)                         80   -LT-9
#Undergraduate school (13-16) aged learners    51   -LT-10
#Graduate (17-20)                         74   -LT-11
#Graduate school (17-20) aged learners    30   -LT-12
#K-12 classroom teachers    94   -LT-13

# %%
#I2) Pre-service-service STEM Teachers Targeted? Specify.

#print(df.columns.values)

#print(df['I2) Pre-service-service STEM Teachers Targeted? Specify.'].value_counts())
#print("\n")
#print(df['Unnamed: 65'].value_counts())
#print("\n")
#print(df['Unnamed: 66'].value_counts())
#print("\n")
#print(df['Unnamed: 67'].value_counts())
#print("\n")
#print(df['Unnamed: 68'].value_counts())
#print("\n")

labels =["Pre-service","Pre-K","Elementary (K-5)","Middle (6-8)","High (9-12)"]
          
sizes =[40,13,36,46,47]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)

plt.pie(sizes,labels=labels,
       autopct='%1.1f%%', shadow=True, startangle=140)

#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.title("Pre-service-service STEM Teachers Targeted",color="blue")
plt.show()

# %%
#I3) In-service STEM Teachers Targeted? Specify.
#print(df.columns.values)

#print(df['I3) In-service STEM Teachers Targeted? Specify.'].value_counts())
#print("\n")
#print(df['Unnamed: 70'].value_counts())
#print("\n")
#print(df['Unnamed: 71'].value_counts())
#print("\n")
#print(df['Unnamed: 72'].value_counts())
#print("\n")
#print(df['Unnamed: 73'].value_counts())
#print("\n")

labels =["In-service","Pre-K","Elementary (K-5)","Middle (6-8)","High (9-12)"]
          
sizes =[89,21,63,87,83]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)

plt.pie(sizes,labels=labels,
       autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("In-service STEM Teachers Targeted",color="blue")
#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()

# %%
#print(df.columns.values)

import pandas as pd
data = pd.read_excel('C:/Users/dell/Downloads/datamodified.xls')
data["I4) Adult Learners Targeted?"].value_counts().plot(kind = "bar")

# %%
#data['I6) K-12 Staff/Administrators Targeted? Specify.'].value_counts()
#print("\n")
#data['Unnamed: 77'].value_counts()
#print("\n")
#data['Unnamed: 78'].value_counts()
#print("\n")
#data['Unnamed: 79'].value_counts()
#print("\n")
d#ata['Unnamed: 80'].value_counts()
labels =["K-12 staff/leaders/administrators","Pre-K","Elementary (K-5)","Middle School (6-8)","High School (9-12)"]
sizes = [25,10,19,23,24]

#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)

plt.pie(sizes,labels=labels,
       autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("K-12 Staff/Administrators Targeted",color="blue")
#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()

# %%
#data['I7) Post-secondary Instructors Targeted? Specify.'].value_counts()
#data['Unnamed: 82'].value_counts()
#data['Unnamed: 83'].value_counts()
#data['Unnamed: 84'].value_counts()

objects =["Post-secondary instructors","Undergraduate Instructors (13-16)","Graduate Instructors (17-20)","Post Graduate"]
performance = [65,59,35,15]


y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5,color ="yellow")
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Frequency')
plt.title('Post-secondary Instructors Targeted')
 
plt.show()

# %%
#data['I8) Post-secondary Staff Targeted? Specify.'].value_counts()
#data['Unnamed: 86'].value_counts()
#data['Unnamed: 87'].value_counts()
#data['Unnamed: 88'].value_counts()

objects =["Post-secondary deans/leaders/administrators","Undergraduate","Undergraduate (13-16)","Graduate (17-20)","Graduate","Post Graduate"]
performance = [36,17,15,14,12,15]


y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5,color ="yellow")
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Frequency')
plt.title('Post-secondary Staff Targeted')
 
plt.show()

# %%
#data['I11) Other Target Group?'].value_counts()
#data['Unnamed: 92'].value_counts() it has 32 unique but frequency is 1 for all


#data['J) Focus on Underrepresented Groups in STEM'].value_counts()
#data['Unnamed: 96-106'].value_counts()

objects =["No","Yes","Hispanic or Latino","Black or African American","Native Hawaiian / Other Pacific Islander","American Indian / Alaska Native","Economically disadvantaged",
         "Female","Male","Persons with disabilities","Rural","Urban","Other"]
performance = [173,79,22,25,18,20,17,14,1,11,8,5,13]
y_pos = np.arange(len(objects))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, performance, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Frequency')
plt.title('Focus on Underrepresented Groups in STEM')
 
plt.show()

# %%
#data['K) Eligibility Restrictions'].value_counts()
#data['Unnamed: 109-11'].value_counts()
objects =["Yes","No","U.S. citizens","Permanent residents","Nationals"]
performance = [128,124,121,72,56]

# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(objects,performance,s =100)
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.title('Eligibility Restrictions')
plt.show()

# %%
#data['L) Minority Serving Institutions'].value_counts()
#data['Unnamed: 113-118'].value_counts()
objects =["Yes","No","All types of Minority Institutions","Historically Black Colleges or Universities","Hispanic-Serving Institutions",
         "Alaska Native-Serving Institutions","Native Hawaiian-Serving Institutions","Tribal Colleges and Universities"]
performance = [27,152,17,5,3,2,2,3]

# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(objects,performance,s =100)
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.title('Minority Serving Institutions')
plt.show()

# %%
#data["N) STEM Discipline Focus"].value_counts()
#data['Unnamed: 130-141'].value_counts()
objects =["STEM (no specific subject or field required)","Science - Physical sciences (including physics, chemistry, astronomy, materials science)",
         "Science - Biological science","Science - Earth, atmospheric, ocean, or planetary science","Science - Agricultural science","Science - Environmental science",
         "Science - Computer science","Technology (no specific subject or field required)","Engineering (no specific subject or field required)",
         "Mathematics or statistics","Other"]
performance = [48,48,36,56,4,39,21,34,40,33,150]
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(objects,performance,s =100)
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.title('STEM Discipline Focus')
plt.show()

# %%
#data["O) Organization or Individual Funded"].value_counts()
#data['Unnamed: 143-153'].value_counts()

objects =["Federally funded research and development centers, experimental stations, other federal STEM research facilities",
         "Individuals","Four-year institutions of higher education","Two-year institutions of higher education or community colleges",
         "State systems of higher education","State education agency or state government","School districts or school","Informal education institutions or organizations",
         "Professional societies","Grants to STEM professionals or companies","Other"]
performance = [42,17,94,48,21,23,27,51,33,45,50]
y_pos = np.arange(len(objects))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, performance, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Frequency')
plt.title('Organization or Individual Funded')
 
plt.show()

#print(df.columns.values[139:200])

# %%
#data["P) External Funding Allocation"].value_counts()
#data['Unnamed: 155-159'].value_counts()
objects =["Formula (to government entities)","Competitive (grants or contracts)","Non-competitive","Other"]
performance = [6,93,20,50]
y_pos = np.arange(len(objects))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, performance, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Frequency')
plt.title('External Funding Allocation')
 
plt.show()

# %%
data['Q) Legislation Required to Shift Focus?'].value_counts()

labels =["No","Yes","Don't know"]
sizes = [119,76,56]

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)

plt.pie(sizes,labels=labels,colors=colors,
       autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Legislation Required to Shift Focus",color="blue")
#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()

# %%
#data["S) Investment Partnerships"].value_counts()

labels =["Encouraged","No","Required","Mixed"]
sizes= [61,45,22,11]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)

plt.pie(sizes,labels=labels,colors=colors,
       autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Investment Partnerships",color="blue")
#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()

# %%
#data["T) Partnerships with What Organization Types?"].value_counts()
#data['Unnamed: 188-209'].value_counts()

labels =["Four-year institutions of higher education (bachelor- and/or graduate-degree-granting institutions)",
         "Two-year institution of higher education or community college","Minority institution (MI)",
        "All types of Minority Institutions","Historically Black Colleges or Universities","Hispanic-Serving Institutions",
       "State systems of higher education","Local education agency" ,"State education agency","School district or school",
        "Informal education institution or organization","Professional society","Education research, policy, or evaluation organizations"
        ,"Federal agency","Federally funded research and development center, experimental station, or other federal STEM research facility",
        "Industry","Non-profit Organization","Not applicable","other"]
sizes= [71,49,43,34,6,5,25,36,24,58,57,39,34,32,32,39,60,16,35]

# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(labels,sizes,s =100,color="red")
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.title('Partnerships with What Organization Types')
plt.show()

# %%
#data["U) Measured Outputs"].value_counts()
#data['Unnamed: 211-224'].value_counts()
labels =["Number of learners (any age) served","Number of educators served","Number of adults served","Number of K-12 schools served","Number institutions of higher education served",
        "Number of school districts served","Number of materials distributed or downloaded from websites","Hours of tutoring, mentoring, or other service provided ",
        "Number of contact hours by audience","Number of degrees or certificates earned","Number of degrees awarded"]
sizes= [352,120,24,53,25,32,41,20,13,54,17]



# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(labels,sizes,s =100,color="red")
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.title('Measured Outputs')
plt.show()

# %%
#data["V) Outcomes Measured"].value_counts()
#data['Unnamed: 237'].value_counts()
labels =["Learner performance","Number or percent of learners who pursue coursework in STEM fields","Learner educational attainment","Number of participants employed by your agency","Number of participants employed in STEM fields","Educator improvement and performance in STEM education instruction"]
sizes= [37,24,27,28,42,29]

# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(labels,sizes,s =100,color="red")
plt.ylabel("frequency")
import pylab as pl
pl.xticks(rotation = 90)
plt.title('Outcomes Measured')
plt.show()

# %%
#data["X) Evaluated Since 2005?"].value_counts()
#data['Unnamed: 239'].value_counts()

labels =["Yes","No"]
sizes= [119,20,]

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

#plt.pie(sizes,labels=labels, colors=colors,
 #      autopct='%1.1f%%', shadow=True, startangle=140)

plt.pie(sizes,labels=labels,colors=colors,
       autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Evaluated Since 2005",color="blue")
#plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(5,5) # or (4,4) or (5,5) or whatever
plt.show()

# %%
#data["Y1) Formative Evaluation Type"].value_counts()
#data['Unnamed: 244'].value_counts()

labels =["INDEPENDENT","INTERNAL","no"]
sizes= [43,43,72]
y_pos = np.arange(len(labels))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, sizes, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, labels,rotation=90)
plt.ylabel('Frequency')
plt.title('Formative Evaluation Type')
 
plt.show()

# %%
#data["Y2) Summative Evaluation Type"].value_counts()
#data['Unnamed: 247'].value_counts()
labels =["INDEPENDENT","INTERNAL","no"]
sizes= [41,28,80]
y_pos = np.arange(len(labels))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, sizes, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, labels,rotation=90)
plt.ylabel('Frequency')
plt.title('Summative Evaluation Type')
 
plt.show()

# %%
#data["Y3) Process or Implementation Evaluation Type"].value_counts()
#data['Unnamed: 250'].value_counts()
labels =["INDEPENDENT","INTERNAL","no"]
sizes= [40,38,77]
y_pos = np.arange(len(labels))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, sizes, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, labels,rotation=90)
plt.ylabel('Frequency')
plt.title('Process or Implementation Evaluation Type')
 
plt.show()

# %%
#data["Y4) Portfolio Evaluation/Review Type"].value_counts()
#data['Unnamed: 253'].value_counts()
labels =["INDEPENDENT","INTERNAL","no"]
sizes= [32,33,86]
y_pos = np.arange(len(labels))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, sizes, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, labels,rotation=90)
plt.ylabel('Frequency')
plt.title('Portfolio Evaluation/Review Type')
 
plt.show()

# %%
#data["Y5) Expert Review Type"].value_counts()
#data['Unnamed: 255'].value_counts()
labels =["INDEPENDENT","INTERNAL"]
sizes= [47,8]
y_pos = np.arange(len(labels))
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','red','orange','#f1e876','#b18176']

plt.bar(y_pos, sizes, align='center', alpha=0.5,color =colors)
plt.xticks(y_pos, labels,rotation=90)
plt.ylabel('Frequency')
plt.title('Expert Review Type')
 
plt.show()
